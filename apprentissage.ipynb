# %% [markdown]
# introduction a python :

# %% [markdown]
# variable : str, nbr , bool , real , .....

# %%
#number 
a = 12 #number 
b = 13 #number
result = a+b 
print(result)
# Out:
# 0.9230769230769231

# %%
#str
nom = 'RAZAKANAIVO' 
prenom = 'Niaina' 
result = nom + ' ' + prenom 
print(result) 
maj = result.lower()
print(maj) 
print(len(result))

for mot in result :
    print(mot, end=',' )
# Out:
# RAZAKANAIVO Niaina
# razakanaivo niaina
# 18
# R,A,Z,A,K,A,N,A,I,V,O, ,N,i,a,i,n,a,
